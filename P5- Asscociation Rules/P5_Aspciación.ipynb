# %% [markdown]
# # Práctica 5: Reglas de asociación
# ## Tratamiento Inteligente de Datos
#
# Autor: Pedro Manuel Flores Crespo

# %% [markdown]
# Algunas importaciones básicas

# %%
import pandas as pd 
from sklearn import tree
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preprocesamiento

# %%
prestamo = pd.read_excel("prestamo-data.xls")
prestamo.head()
# Out:
#    Age  Experience  Income  ...  CD Account  Online  CreditCard
# 0   25           1      49  ...           0       0           0
# 1   45          19      34  ...           0       0           0
# 2   39          15      11  ...           0       0           0
# 3   35           9     100  ...           0       0           0
# 4   35           8      45  ...           0       0           1
#
# [5 rows x 13 columns]

# %%
prestamo.shape
# Out:
# (5000, 13)

# %%
prestamo.dtypes
# Out:
# Age                     int64
# Experience              int64
# Income                  int64
# ZIP Code                int64
# Family                  int64
# CCAvg                 float64
# Education               int64
# Mortgage                int64
# Personal Loan           int64
# Securities Account      int64
# CD Account              int64
# Online                  int64
# CreditCard              int64
# dtype: object

# %%
prestamo.describe()
# Out:
#                Age   Experience  ...       Online   CreditCard
# count  5000.000000  5000.000000  ...  5000.000000  5000.000000
# mean     45.338400    20.104600  ...     0.596800     0.294000
# std      11.463166    11.467954  ...     0.490589     0.455637
# min      23.000000    -3.000000  ...     0.000000     0.000000
# 25%      35.000000    10.000000  ...     0.000000     0.000000
# 50%      45.000000    20.000000  ...     1.000000     0.000000
# 75%      55.000000    30.000000  ...     1.000000     1.000000
# max      67.000000    43.000000  ...     1.000000     1.000000
#
# [8 rows x 13 columns]

# %%
prestamo.columns
# Out:
# Index(['Age', 'Experience', 'Income', 'ZIP Code', 'Family', 'CCAvg',
#        'Education', 'Mortgage', 'Personal Loan', 'Securities Account',
#        'CD Account', 'Online', 'CreditCard'],
#       dtype='object')

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.distplot(prestamo['Age'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Experience'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Income'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['ZIP Code'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Family'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['CCAvg'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Education'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Mortgage'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Personal Loan'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Securities Account'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['CD Account'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['Online'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('darkgrid')
sns.distplot(prestamo['CreditCard'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Realizamos el preprocesamiento de los datos

# %%
prestamo = prestamo.drop('Age', 1)
prestamo = prestamo.drop('Experience', 1)
prestamo = prestamo.drop('ZIP Code', 1)
#prestamo = prestamo.drop('Family', 1)
prestamo = prestamo.drop('Income', 1)
#prestamo = prestamo.drop('CCAvg', 1)
#prestamo = prestamo.drop('Mortgage', 1)
#prestamo = prestamo.drop('Education', 1)

# %%
prestamo['Mortgage']=pd.cut(x=prestamo['Mortgage'], bins=[-1,1,700], labels=[0,1])
prestamo['CCAvg']=pd.cut(x=prestamo['CCAvg'], bins=[-1,3,700], labels=[0,1])
#prestamo['Age']=pd.cut(x=prestamo['Age'], bins=[-1,30,60,120], labels=[1,2,3])
#prestamo['Income']=pd.cut(x=prestamo['Income'], bins=[-1,100,500], labels=[1,2])

# %%
prestamo['Family_1'] = [(False if num!=1 else True) for i, num in enumerate(prestamo['Family'])]
prestamo['Family_2'] = [(False if num!=2 else True) for i, num in enumerate(prestamo['Family'])]
prestamo['Family_3'] = [(False if num!=3 else True) for i, num in enumerate(prestamo['Family'])]
prestamo['Family_4'] = [(False if num!=4 else True) for i, num in enumerate(prestamo['Family'])]

# %%
prestamo['Education_1'] = [(False if num!=1 else True) for i, num in enumerate(prestamo['Education'])]
prestamo['Education_2'] = [(False if num!=2 else True) for i, num in enumerate(prestamo['Education'])]
prestamo['Edcuation_3'] = [(False if num!=3 else True) for i, num in enumerate(prestamo['Education'])]

# %%
prestamo['CCAvg_bajo'] = [(False if num!=0 else True) for i, num in enumerate(prestamo['CCAvg'])]
prestamo['CCAvg_alto'] = [(False if num!=1 else True) for i, num in enumerate(prestamo['CCAvg'])]

# %%
#prestamo['Age_jove'] = [(False if num!=1 else True) for i, num in enumerate(prestamo['Age'])]
#prestamo['Age_mediana'] = [(False if num!=2 else True) for i, num in enumerate(prestamo['Age'])]
#prestamo['Age_mayor'] = [(False if num!=3 else True) for i, num in enumerate(prestamo['Age'])]

# %%
#prestamo['Income_Bajo'] = [(False if num!=1 else True) for i, num in enumerate(prestamo['Income'])]
#prestamo['Income_Alto'] = [(False if num!=2 else True) for i, num in enumerate(prestamo['Income'])]

# %%
prestamo = prestamo.drop('Family', 1)
prestamo = prestamo.drop('Education', 1)
prestamo = prestamo.drop('CCAvg', 1)
#prestamo = prestamo.drop('Age', 1)
#prestamo = prestamo.drop('Income', 1)

# %%
prestamo.head()
# Out:
#   Mortgage  Personal Loan  ...  CCAvg_bajo  CCAvg_alto
# 0        0              0  ...        True       False
# 1        0              0  ...        True       False
# 2        0              0  ...        True       False
# 3        0              0  ...        True       False
# 4        0              0  ...        True       False
#
# [5 rows x 15 columns]

# %% [markdown]
# Convertimos a booleanos

# %%
prestamo = prestamo.astype(bool)

# %%
prestamo.head()
# Out:
#    Mortgage  Personal Loan  ...  CCAvg_bajo  CCAvg_alto
# 0     False          False  ...        True       False
# 1     False          False  ...        True       False
# 2     False          False  ...        True       False
# 3     False          False  ...        True       False
# 4     False          False  ...        True       False
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Apriori

# %% [markdown]
# Calculamos los itemsets frecuentes

# %%
from mlxtend.frequent_patterns import apriori

# cambiar valores
frequent_itemsets_ap = apriori(prestamo, min_support=0.01, use_colnames=True)
print(frequent_itemsets_ap)
# Out:
#      support                                           itemsets
# 0     0.3076                                         (Mortgage)
# 1     0.0960                                    (Personal Loan)
# 2     0.1044                               (Securities Account)
# 3     0.0604                                       (CD Account)
# 4     0.5968                                           (Online)
# 5     0.2940                                       (CreditCard)
# 6     0.2944                                         (Family_1)
# 7     0.2592                                         (Family_2)
# 8     0.2020                                         (Family_3)
# 9     0.2444                                         (Family_4)
# 10    0.4192                                      (Education_1)
# 11    0.2806                                      (Education_2)
# 12    0.3002                                      (Edcuation_3)
# 13    0.8302                                       (CCAvg_bajo)
# ...

# %% [markdown]
# Obtenemos las reglas de asociación

# %%
from mlxtend.frequent_patterns import association_rules

rules_ap = association_rules(frequent_itemsets_ap, metric="confidence", min_threshold=0.75)
len(rules_ap)
# Out:
# 218

# %% [markdown]
# Ordenamos según el lift

# %%
pd.set_option('display.max_rows', None)
rules_ap.sort_values(by='lift', ascending=False)
# Out:
#                                            antecedents  ... conviction
# 207           (Securities Account, Online, CreditCard)  ...   6.902933
# 201    (CCAvg_alto, Online, Personal Loan, CreditCard)  ...        inf
# 117           (Securities Account, Online, CreditCard)  ...        inf
# 110                (Online, Personal Loan, CreditCard)  ...        inf
# 204  (Securities Account, Online, CCAvg_bajo, Credi...  ...        inf
# 25                 (Securities Account, Personal Loan)  ...   6.264000
# 28                              (Family_3, CCAvg_alto)  ...   9.944000
# 115                     (Family_3, Online, CCAvg_alto)  ...   9.492000
# 116                  (Education_2, Online, CCAvg_alto)  ...   5.604800
# 29                           (Education_2, CCAvg_alto)  ...   5.537000
# 27                            (CD Account, CCAvg_alto)  ...   4.848727
# 112                   (CD Account, Online, CCAvg_alto)  ...   4.437818
# ...

# %% [markdown]
# Ordenamos según la confianza

# %%
rules_ap.sort_values(by='confidence', ascending=False)
# Out:
#                                            antecedents  ... conviction
# 117           (Securities Account, Online, CreditCard)  ...        inf
# 201    (CCAvg_alto, Online, Personal Loan, CreditCard)  ...        inf
# 204  (Securities Account, Online, CCAvg_bajo, Credi...  ...        inf
# 110                (Online, Personal Loan, CreditCard)  ...        inf
# 40                              (CD Account, Family_2)  ...  27.014400
# 134                 (CD Account, Family_2, CreditCard)  ...  23.385600
# 154              (Education_2, CD Account, CCAvg_bajo)  ...  20.563200
# 42                              (CD Account, Family_4)  ...  14.112000
# 139                 (CD Account, CreditCard, Family_4)  ...  11.088000
# 83                  (CD Account, Mortgage, CCAvg_bajo)  ...   8.870400
# 46                            (CD Account, CCAvg_bajo)  ...   8.243200
# 186     (CD Account, Mortgage, CCAvg_bajo, CreditCard)  ...   8.198400
# ...

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(x=rules_ap.support, 
                y=rules_ap.confidence, 
                size=rules_ap.lift, 
                sizes=(10, 200),
                hue=rules_ap.lift, 
                ax=ax).set_title("REGLAS DE ASOCIACIÓN")
# Out:
# Text(0.5, 1.0, 'REGLAS DE ASOCIACIÓN')
